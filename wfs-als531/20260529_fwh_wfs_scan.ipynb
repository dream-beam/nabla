# %% [markdown]
# # WFS controls for operation at ALS beamline 5.3.1
#
# Authors: khchan@lbl.gov, francisho@lbl.gov, awojdyla@lbl.gov, walangrizolli@lbl.gov
#
# We added capture of the beam a the sample. It doesn't quite work but we're close.
# We want to acquire a nice grid scanbender/energy without any binning.
#
# We want to add relevant metadata (exposure time , pixel size/camera model, binning) so that we can scale data accordingly (effective flux, effective size)

# %% [markdown]
# # SETUP

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from PIL import Image

from tiled.client import from_uri

import wfs_live as wfl

# %% [markdown]
# ## Setting up epics/ophyd/bluesky/tiled

# %%
from ophyd import EpicsMotor
Obender = EpicsMotor('bl531_esp300:m101_bend_um', name='bender_um')
Obender.low_limit_travel.set(-2000)

# here is the wrapper
#from h01 import mono_energy
# Out:
# Status(obj=EpicsSignal(read_pv='bl531_esp300:m101_bend_um.LLM', name='bender_um_low_limit_travel', parent='bender_um', timestamp=1780098805.3647983, auto_monitor=True, string=False, write_pv='bl531_esp300:m101_bend_um.LLM', limits=False, put_complete=False), done=False, success=False)

# %%
import sys
sys.path.append('/home/bl531/python/nabla/')
from nabla.nophyd import MonoEnergy, BaslerDetector, BCSMotor

# %%
mono_energy = MonoEnergy('', name='mono_energy')  # Empty prefix since motor has full PV

# %%
BASLER_FILES_ROOT = "/mnt/data531"
BASLER_5472_IMAGE_DIR = "scans/%Y/%m/%d/basler5472"   # e.g. "20251113_test/%Y/%m/%d" if you want date subdirs
BASLER_2448_IMAGE_DIR = "scans/%Y/%m/%d/basler2448"   # e.g. "20251113_test/%Y/%m/%d" if you want date subdirs

try:
    basler_5472 = BaslerDetector(
        "BL531acA5427:",
        name="basler_5472",
        image_dir=BASLER_5472_IMAGE_DIR,
    )

    # Stage signals — set before each acquisition, restored after
    basler_5472.cam.stage_sigs['image_mode']    = 'Single'
    basler_5472.cam.stage_sigs['num_images']    = 1
    basler_5472.cam.stage_sigs['acquire_time']  = 2
    basler_5472.cam.stage_sigs['acquire_period'] = 0.5

    basler_5472.tiff.stage_sigs['file_template'] = '/%s%s_%3.3d.tif'
    # Enable TIFF capture when staged
    basler_5472.tiff.stage_sigs['enable']        = 1
    basler_5472.tiff.stage_sigs['auto_save']     = 'Yes'
    basler_5472.tiff.stage_sigs['file_write_mode'] = 'Single'

    # Only expose the TIFF plugin through read/describe so Tiled picks it up
    basler_5472.read_attrs      = ['tiff']
    basler_5472.tiff.read_attrs = []

    print("Basler camera connected successfully.")

except Exception as e:
    print(f"Error instantiating Basler camera: {e}")
    print("Is the EPICS IOC running? Check PV prefix 'BL531acA5427:'")

try:
    basler_2448 = BaslerDetector(
        "BL531a2A2448:",
        name="basler_2448",
        image_dir=BASLER_2448_IMAGE_DIR,
    )

    # Stage signals — set before each acquisition, restored after
    basler_2448.cam.stage_sigs['image_mode']    = 'Single'
    basler_2448.cam.stage_sigs['num_images']    = 1
    basler_2448.cam.stage_sigs['acquire_time']  = 1
    basler_2448.cam.stage_sigs['acquire_period'] = 1.1
    # basler_2448.cam.stage_sigs['trigger_mode'] = 'Off' 
    basler_2448.cam.stage_sigs['array_callbacks'] = 1
    # basler_2448.tiff.stage_sigs['file_template'] = '/%s%s_%3.3d.tif'
    # Enable TIFF capture when staged
    # basler_2448.tiff.stage_sigs['enable']        = 1
    # basler_2448.tiff.stage_sigs['auto_save']     = 'Yes'
    # basler_2448.tiff.stage_sigs['file_write_mode'] = 'Single'
    
    # Only expose the TIFF plugin through read/describe so Tiled picks it up
    # basler_2448.read_attrs      = ['tiff']
    # basler_2448.tiff.read_attrs = []

    print("Basler camera connected successfully.")

except Exception as e:
    print(f"Error instantiating Basler camera: {e}")
    print("Is the EPICS IOC running? Check PV prefix 'BL531a2A2448:'")
# Out:
# Basler camera connected successfully.
# Error instantiating Basler camera: Failed to connect to all signals: basler_2448_cam.cam.gain (BL531a2A2448:cam1:Gain), basler_2448_cam.cam.pixel_format (BL531a2A2448:cam1:PixelFormat), basler_2448_cam.cam.exposure_auto (BL531a2A2448:cam1:ExposureAuto), basler_2448_cam.cam.gain_auto (BL531a2A2448:cam1:GainAuto), basler_2448_cam.cam.acquire_rbv (BL531a2A2448:cam1:Acquire_RBV)
# Is the EPICS IOC running? Check PV prefix 'BL531a2A2448:'

# %%
import bcs_tcp

# ============================================================
# BCS TCP connection (same as your existing setup)
# ============================================================

ALSU_BOSS_IP = "131.243.80.251"
(host_ip_addr, host_port, host_timeout) = (ALSU_BOSS_IP, 55000, 5)
bcs = bcs_tcp.connection(host_ip_addr, host_port, host_timeout)

# Motor id strings (same as before)
bcs_id_linear = 'Galil x.20 A'
bcs_id_rotary = 'Galil x.20 B'

# Quick sanity check
str_pos_lin_mm = bcs.GetMotorPos(bcs_id_linear)
pos_lin_mm = float(str_pos_lin_mm.rstrip())
print(f'linear stage position is {pos_lin_mm} mm')

# ============================================================
# Instantiate BCSMotor ophyd objects
# ============================================================

bcs_linear_motor = BCSMotor(
    bcs=bcs,
    motor_id=bcs_id_linear,
    settle_time=0.5,
    tolerance=0.001,
    name='bcs_linear_motor',
)

bcs_rotary_motor = BCSMotor(
    bcs=bcs,
    motor_id=bcs_id_rotary,
    settle_time=0.5,
    tolerance=0.01,
    name='bcs_rotary_motor',
)

# ============================================================
# Quick checks
# ============================================================

print(f'Linear motor position : {bcs_linear_motor.position} mm')
print(f'Rotary motor position : {bcs_rotary_motor.position} deg')
print(bcs_linear_motor)
print(bcs_rotary_motor)
# Out:
# linear stage position is 4.399955 mm
# Linear motor position : 4.399955 mm
# Rotary motor position : 0.0 deg
# BCSMotor(name='bcs_linear_motor', motor_id='Galil x.20 A', position=4.4000 mm)
# BCSMotor(name='bcs_rotary_motor', motor_id='Galil x.20 B', position=0.0000 mm)

# %%
# The queue server must include the "keep_re" parameter which prevents the RE in this startup script from being overwritten

from bluesky import RunEngine

RE = RunEngine({})

from bluesky.callbacks.best_effort import BestEffortCallback
from bluesky.callbacks.tiled_writer import TiledWriter
from tiled.server import SimpleTiledServer
from tiled.client import from_uri

#load the api key from env var
import os
api_key = os.getenv("TILED_SINGLE_USER_API_KEY")
if not api_key:
    raise ValueError("TILED_SINGLE_USER_API_KEY environment variable is not set.")

# Initialize the Tiled server and client
tiled_client = from_uri("http://192.168.10.155:8000", api_key=api_key)
tw = TiledWriter(tiled_client, batch_size=1)
## doesnt work yet because the central server is not configured to accept the resource documents with the local file paths. need to patch the resource documents to replace the local path prefix with the central path prefix before sending to central tiled server.

central_tiled_api_key = os.getenv("CENTRAL_API_KEY")
if not central_tiled_api_key:
    raise ValueError("TILED_SINGLE_USER_API_KEY environment variable is not set.")

central_tiled_client = from_uri("https://tiled.computing.als.lbl.gov/api/v1/metadata/beamlines/bl531/raw", api_key=central_tiled_api_key)


LOCAL_PATH_PREFIX = "mnt/data531"
CENTRAL_PATH_PREFIX = "/global/beegfs/beamlines/bl531/raw"

def patch_ride_filenames(doc: dict):
    """
    a TiledWriter will be sending documents to the central Tiled server.
    For resource documents, we want to patch resource_path;
    Add CENTRAL_PATH_PREFIX in place of LOCAL_PATH_PREFIX as the root key
    Strip LOCAL_PATH_PREFIX from the beginning of resource_path, if it exists
    :param doc_name: Description
    :type doc_name: str
    :param doc: Description
    :type doc: dict
    """    
    resource_path = doc.get("resource_path", "")
    if resource_path.startswith(LOCAL_PATH_PREFIX):
        # Strip LOCAL_PATH_PREFIX and prepend CENTRAL_PATH_PREFIX
        relative_path = resource_path[len(LOCAL_PATH_PREFIX):].lstrip("/")
        new_resource_path = os.path.join(CENTRAL_PATH_PREFIX, relative_path)
        doc["resource_path"] = new_resource_path
        #print(f"Patched resource_path: {resource_path} -> {new_resource_path}")
    return doc

central_tiled_writer = TiledWriter(central_tiled_client, batch_size=1, patches={"resource": patch_ride_filenames})
# uncomment this to connect to central tiled server
# RE.subscribe(central_tiled_writer)

RE.subscribe(tw)

bec = BestEffortCallback()

bec.disable_plots()

# Send all metadata/data captured to the BestEffortCallback.
RE.subscribe(bec)

# add 'baseline' stream with start/stop position of ophyd devices passed into 'sd'
from bluesky.preprocessors import SupplementalData
sd = SupplementalData()
RE.preprocessors.append(sd)
sd.baseline = []
if sd:
#    sd.baseline = [mono_energy, Obender, bcs_linear_motor, basler_5472.cam.stage_sigs['acquire_time']] #for now just adding these two. add more as needed.
    sd.baseline = [mono_energy, Obender, bcs_linear_motor] #for now just adding these two. add more as needed.
# Out:
# [BCSMotor] bcs_linear_motor: moving to 4.4000 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4000 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4010 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4010 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4020 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4020 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4030 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4030 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4040 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4040 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4050 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4050 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4060 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4060 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4070 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4070 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4080 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4080 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4090 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4090 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4100 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4100 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4100 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4100 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4110 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4110 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4120 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4120 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4130 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4130 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4140 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4140 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4150 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4150 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4160 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4160 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4170 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4170 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4180 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4180 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4190 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4190 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4200 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4200 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4210 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4210 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4220 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4220 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4230 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4230 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4240 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4240 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4250 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4250 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4260 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4260 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4270 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4270 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4280 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4280 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4290 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4290 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4300 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4300 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4310 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4310 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4320 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4320 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4330 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4330 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4340 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4340 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4350 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4350 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4360 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4360 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4370 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4370 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4380 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4380 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4390 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4390 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4400 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4400 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4410 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4410 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4420 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4420 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4430 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.4430 mm
# [BCSMotor] bcs_linear_motor: moving to 4.4440 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 4.
mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.4000 mm
# [BCSMotor] bcs_linear_motor: moving to 7.4100 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.4100 mm
# [BCSMotor] bcs_linear_motor: moving to 7.8990 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.8990 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9000 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9000 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9010 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9010 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9020 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9020 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9030 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9030 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9040 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9040 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9050 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9050 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9060 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9060 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9070 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9070 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9080 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9080 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9090 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9090 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9100 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9100 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9110 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9110 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9120 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9120 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9130 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9130 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9140 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9140 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9150 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9150 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9160 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9160 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9170 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9170 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9180 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9180 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9190 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9190 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9200 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9200 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9210 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9210 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9220 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9220 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9230 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9230 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9240 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9240 mm
# [BCSMotor] bcs_linear_motor: moving to 7.9250 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 7.9250 mm
# ...
# [BCSMotor] bcs_linear_motor: moving to 8.9570 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9570 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9580 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9580 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9590 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9590 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9600 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9600 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9610 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9610 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9620 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9620 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9630 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9630 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9640 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9640 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9650 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9650 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9660 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9660 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9670 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9670 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9680 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9680 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9690 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9690 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9700 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9700 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9710 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9710 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9720 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9720 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9730 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9730 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9740 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9740 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9750 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9750 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9760 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9760 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9770 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9770 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9780 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9780 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9790 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9790 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9800 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9800 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9810 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9810 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9820 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9820 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9830 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9830 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9840 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9840 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9850 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9850 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9860 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9860 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9870 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9870 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9880 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9880 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9890 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9890 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9900 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9900 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9910 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9910 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9920 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9920 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9930 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9930 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9940 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9940 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9950 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9950 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9960 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9960 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9970 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9970 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9980 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9980 mm
# [BCSMotor] bcs_linear_motor: moving to 8.9990 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 8.9990 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0000 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0000 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0010 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0010 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0020 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0020 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0030 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0030 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0040 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0040 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0050 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0050 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0060 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0060 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0070 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0070 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0080 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0080 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0090 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0090 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0100 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0100 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0110 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0110 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0120 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0120 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0130 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0130 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0140 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0140 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0150 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0150 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0160 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0160 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0170 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0170 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0180 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0180 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0190 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0190 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0200 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0200 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0210 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0210 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0220 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0220 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0230 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0230 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0240 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0240 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0250 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0250 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0260 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0260 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0270 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0270 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0280 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0280 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0290 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0290 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0300 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0300 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0310 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0310 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0320 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0320 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0330 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0330 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0340 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0340 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0350 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0350 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0360 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0360 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0370 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0370 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0380 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0380 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0390 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0390 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0400 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0400 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0410 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0410 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0420 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0420 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0430 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0430 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0440 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0440 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0450 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0450 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0460 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0460 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0470 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0470 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0480 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0480 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0490 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0490 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0500 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0500 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0510 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0510 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0520 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0520 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0530 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0530 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0540 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0540 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0550 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0550 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0560 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0560 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0570 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0570 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0580 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0580 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0590 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0590 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0600 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0600 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0610 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0610 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0620 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0620 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0630 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0630 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0640 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0640 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0650 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0650 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0660 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0660 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0670 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0670 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0680 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0680 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0690 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0690 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0700 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0700 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0710 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0710 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0720 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0720 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0730 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0730 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0740 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0740 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0750 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0750 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0760 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0760 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0770 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0770 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0780 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0780 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0790 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0790 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0800 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0800 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0810 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0810 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0820 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0820 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0830 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0830 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0840 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0840 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0850 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0850 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0860 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0860 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0870 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0870 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0880 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0880 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0890 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0890 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0900 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0900 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0910 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0910 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0920 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0920 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0930 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0930 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0940 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0940 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0950 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0950 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0960 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0960 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0970 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0970 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0980 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0980 mm
# [BCSMotor] bcs_linear_motor: moving to 9.0990 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.0990 mm
# [BCSMotor] bcs_linear_motor: moving to 9.1000 mm
# [BCSMotor] bcs_linear_motor: done. Final position = 9.1000 mm

# %% [markdown]
# ## Check data acquisition

# %%
from bluesky import plans as bp
sd.baseline = [mono_energy, Obender, bcs_linear_motor]

# cam_model = basler_5472.cam.model.read()['basler_5472_cam_model']['value']
objective_model = "Mitutoyo Plan Apo HR 5X"
# exp_time_s = basler_5472.cam.stage_sigs['acquire_time']
pixel_size_um = 2.4
binx = basler_5472.cam.bin_x.read()['basler_5472_cam_bin_x']['value']
biny = basler_5472.cam.bin_y.read()['basler_5472_cam_bin_y']['value']
objective_mag = 5
effective_pixel_size_um = pixel_size_um * binx / objective_mag

# md={"exposure time [s]": f"{exp_time_s}", 
#     "pixel size [um]": f"{pixel_size_um}", 
#     "binning": f"{binx}x{biny}", 
#     "effective pixel size [um]": f"{effective_pixel_size_um}", 
#     "camera model": f"{cam_model}", 
#     "objective model": f"{objective_model}"
# }
md = {
    'pixel size [um]': f"{pixel_size_um}", 
    'binning': f"{binx}x{biny}",
    'effective pixel size [um]': f"{effective_pixel_size_um}", 
    'objective model': f"{objective_model}",   
}

uid = RE(bp.count([basler_5472], num=1, md = md))
# Out:
# Transient Scan ID: 3     Time: 2026-05-29 17:29:06
# Persistent Unique Scan ID: '8d79b5b5-fff7-4a96-88bb-d7a498db9c90'
# New stream: 'baseline'
# Start-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8001.278945132818              |
# |         mono_energy_mono_angle | 20.753                         |
# |                      bender_um | -1999.98627                    |
# |               bcs_linear_motor | 4.399955                       |
# +--------------------------------+--------------------------------+
# New stream: 'primary'
# +-----------+------------+
# |   seq_num |       time |
# +-----------+------------+
# |         1 | 17:29:09.6 |
# +-----------+------------+
# generator count ['8d79b5b5'] (scan num: 3)
# End-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8001.278945132818              |
# |         mono_energy_mono_angle | 20.753                         |
# |                      bender_um | -1999.98627                    |
# |               bcs_linear_motor | 4.399955                       |
# +--------------------------------+--------------------------------+

# %%
db = tiled_client[uid]

# Metadata: Hardware-reported; stored in config
cam   = db['primary'].metadata['configuration']['basler_5472']['data']
exp_time_s   = cam['basler_5472_cam_acquire_time']
camera_model = cam['basler_5472_cam_model']

# Descriptive (from md; .get())
start = db.metadata['start']
pixel_size_um           = start.get('pixel size [um]')
binning                 = start.get('binning')
effective_pixel_size_um = start.get('effective pixel size [um]')
objective_model         = start.get('objective model')

print(f"Camera:          {camera_model}")
print(f"Objective:       {objective_model}")
print(f"Pixel size:      {pixel_size_um} µm  (binning: {binning})")
print(f"Effective pixel: {effective_pixel_size_um} µm")
print(f"Exposure time:   {exp_time_s} s")
# Out:
# Camera:          acA5472-5gm
# Objective:       Mitutoyo Plan Apo HR 5X
# Pixel size:      2.4 µm  (binning: 1x1)
# Effective pixel: 0.48 µm
# Exposure time:   2.0 s

# %%
# Metadata
wfs_chip_pos_mm = db['baseline']['bcs_linear_motor'].read()
energy_eV = db['baseline']['mono_energy_energy_eV'].read()
bender_um = db['baseline']['bender_um'].read()

print(f"WFS chip position (mm): {wfs_chip_pos_mm}")
print(f"Mono energy (eV): {energy_eV}")
print(f"Bender position (µm): {bender_um}")

# Data arrays (slow)
images    = db['primary']['basler_5472_image'].read()     
# energy_eV = db['primary']['mono_energy_energy_eV'].read() 
# bender_um = db['primary']['bender_um'].read() 

# Print summaries
print(f"\nImages shape: {images.shape}  (n_frames × height × width)")
# print(f"Energy range: {energy_eV.min():.1f} – {energy_eV.max():.1f} eV")
# print(f"       shape: {energy_eV.shape}")
# print(f"Bender range: {bender_um.min():.1f} – {bender_um.max():.1f} µm")
# print(f"       shape: {bender_um.shape}")
# Out:
# WFS chip position (mm): [4.399955 4.399955]
# Mono energy (eV): [8001.27894513 8001.27894513]
# Bender position (µm): [-1999.98627 -1999.98627]
#
# Images shape: (1, 3000, 1100)  (n_frames × height × width)

# %%
plt.figure(figsize=(20, 8))
plt.imshow(images[0, :, :].T, cmap='hot')
plt.title('WFS data')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.imshow(images[0, :, :].T, cmap='hot')
plt.title('WFS data')
plt.show()

# %% [markdown]
# # SCANS

# %% [markdown]
# ## Trials

# %% [markdown]
# ### Count

# %%
uid = RE(bp.count([basler_5472], num=1, md = md))
# Out:
# Transient Scan ID: 4     Time: 2026-05-29 18:08:20
# Persistent Unique Scan ID: '31975a86-8951-43c4-bb22-d4d3617a5ff2'
# New stream: 'baseline'
# Start-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8001.278945132818              |
# |         mono_energy_mono_angle | 20.753                         |
# |                      bender_um | -1999.98627                    |
# |               bcs_linear_motor | 4.399955                       |
# +--------------------------------+--------------------------------+
# New stream: 'primary'
# +-----------+------------+
# |   seq_num |       time |
# +-----------+------------+
# |         1 | 18:08:23.6 |
# +-----------+------------+
# generator count ['31975a86'] (scan num: 4)
# End-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8001.278945132818              |
# |         mono_energy_mono_angle | 20.753                         |
# |                      bender_um | -1999.98627                    |
# |               bcs_linear_motor | 4.399955                       |
# +--------------------------------+--------------------------------+

# %% [markdown]
# ### Energy and bender scans

# %%
uid_01 = RE(bp.scan([basler_5472], mono_energy, 7500, 9500, 11))
# Out:
# Transient Scan ID: 5     Time: 2026-05-29 18:09:33
# Persistent Unique Scan ID: '54257af4-47c5-45a3-b465-e0367d454b3f'
# New stream: 'baseline'
# Start-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8001.278945132818              |
# |         mono_energy_mono_angle | 20.753                         |
# |                      bender_um | -1999.98627                    |
# |               bcs_linear_motor | 4.399955                       |
# +--------------------------------+--------------------------------+
# New stream: 'primary'
# +-----------+------------+-----------------------+------------------------+
# |   seq_num |       time | mono_energy_energy_eV | mono_energy_mono_angle |
# +-----------+------------+-----------------------+------------------------+
# |         1 | 18:09:37.8 |              7499.947 |                21.7320 |
# |         2 | 18:09:41.3 |              7699.754 |                21.3260 |
# |         3 | 18:09:44.8 |              7899.692 |                20.9410 |
# |         4 | 18:09:48.3 |              8099.982 |                20.5750 |
# |         5 | 18:09:51.7 |              8299.805 |                20.2280 |
# |         6 | 18:09:55.2 |              8500.121 |                19.8970 |
# |         7 | 18:09:58.6 |              8700.220 |                19.5820 |
# |         8 | 18:10:02.0 |              8900.007 |                19.2820 |
# |         9 | 18:10:05.4 |              9100.156 |                18.9950 |
# |        10 | 18:10:08.7 |              9300.045 |                18.7210 |
# |        11 | 18:10:12.1 |              9499.777 |                18.4590 |
# +-----------+------------+-----------------------+------------------------+
# generator scan ['54257af4'] (scan num: 5)
# End-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 9499.77688200478               |
# |         mono_energy_mono_angle | 18.459                         |
# |                      bender_um | -1999.98627                    |
# |               bcs_linear_motor | 4.399955                       |
# +--------------------------------+--------------------------------+

# %%
db = tiled_client[uid_01]

# Metadata
wfs_chip_pos_mm = db['baseline']['bcs_linear_motor'].read()
bender_um = db['baseline']['bender_um'].read()

print(f"WFS chip position (mm): {wfs_chip_pos_mm}")

# Data arrays (slow)
images    = db['primary']['basler_5472_image'].read()     
energy_eV = db['primary']['mono_energy_energy_eV'].read() 
# bender_um = db['primary']['bender_um'].read() 

# Print summaries
print(f"\nImages shape: {images.shape}  (n_frames × height × width)")
print(f"Energy range: {energy_eV.min():.1f} – {energy_eV.max():.1f} eV")
print(f"       shape: {energy_eV.shape}")
# print(f"Bender range: {bender_um.min():.1f} – {bender_um.max():.1f} µm")
# print(f"       shape: {bender_um.shape}")
# Out:
# WFS chip position (mm): [4.399955 4.399955]
#
# Images shape: (11, 2900, 1100)  (n_frames × height × width)
# Energy range: 7499.9 – 9499.8 eV
#        shape: (11,)

# %%
idx = 5

plt.figure(figsize=(8, 3))
plt.imshow(images[idx].T, cmap='hot', interpolation='nearest', vmax=4000)
plt.title(f'idx={idx}   E={energy_eV[idx]:.0f} eV   bender={bender_um[0]:.0f} µm', fontsize=12)
plt.xlabel('y [pixels]')
plt.ylabel('x [pixels]')
plt.colorbar(label='Intensity [counts]')
plt.tight_layout()
plt.show()

# %%
uid_02 = RE(bp.scan([basler_5472], Obender, -2000, -1400, 13))
# Out:
# Transient Scan ID: 6     Time: 2026-05-29 18:15:01
# Persistent Unique Scan ID: '3d628597-8807-4605-aff1-4337d08e77c5'
# New stream: 'baseline'
# Start-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 9499.77688200478               |
# |         mono_energy_mono_angle | 18.459                         |
# |                      bender_um | -1999.98627                    |
# |               bcs_linear_motor | 4.399955                       |
# +--------------------------------+--------------------------------+
# New stream: 'primary'
# +-----------+------------+------------+
# |   seq_num |       time |  bender_um |
# +-----------+------------+------------+
# |         1 | 18:15:06.7 | -1999.98627 |
# |         2 | 18:15:12.5 | -1950.02052 |
# |         3 | 18:15:18.4 | -1900.02138 |
# |         4 | 18:15:24.1 | -1850.02065 |
# |         5 | 18:15:29.8 | -1800.01992 |
# |         6 | 18:15:35.5 | -1750.02078 |
# |         7 | 18:15:41.3 | -1700.02005 |
# |         8 | 18:15:47.1 | -1650.01932 |
# |         9 | 18:15:52.9 | -1600.01859 |
# |        10 | 18:15:58.7 | -1550.01786 |
# |        11 | 18:16:04.5 | -1500.01872 |
# |        12 | 18:16:10.2 | -1450.01958 |
# |        13 | 18:16:15.9 | -1400.01885 |
# +-----------+------------+------------+
# generator scan ['3d628597'] (scan num: 6)
# End-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 9499.77688200478               |
# |         mono_energy_mono_angle | 18.459                         |
# |                      bender_um | -1400.0188500000002            |
# |               bcs_linear_motor | 4.399955                       |
# +--------------------------------+--------------------------------+

# %%
db = tiled_client[uid_02]

# Metadata
wfs_chip_pos_mm = db['baseline']['bcs_linear_motor'].read()
# bender_um = db['baseline']['bender_um'].read()
energy_eV = db['baseline']['mono_energy_energy_eV'].read()

print(f"WFS chip position (mm): {wfs_chip_pos_mm}")

# Data arrays (slow)
images    = db['primary']['basler_5472_image'].read()     
# energy_eV = db['primary']['mono_energy_energy_eV'].read() 
bender_um = db['primary']['bender_um'].read() 

# Print summaries
print(f"\nImages shape: {images.shape}  (n_frames × height × width)")
# print(f"Energy range: {energy_eV.min():.1f} – {energy_eV.max():.1f} eV")
# print(f"       shape: {energy_eV.shape}")
print(f"Bender range: {bender_um.min():.1f} – {bender_um.max():.1f} µm")
print(f"       shape: {bender_um.shape}")
# Out:
# WFS chip position (mm): [4.399955 4.399955]
#
# Images shape: (13, 2900, 1100)  (n_frames × height × width)
# Bender range: -2000.0 – -1400.0 µm
#        shape: (13,)

# %%
idx = 10

plt.figure(figsize=(8, 3))
plt.imshow(images[idx].T, cmap='hot', interpolation='nearest', vmax=4000)
plt.title(f'idx={idx}   E={energy_eV[0]:.0f} eV   bender={bender_um[idx]:.0f} µm', fontsize=12)
plt.xlabel('y [pixels]')
plt.ylabel('x [pixels]')
plt.colorbar(label='Intensity [counts]')
plt.tight_layout()
plt.show()

# %%
mono_energy.move(8000)
Obender.move(-2000)
# Out:
# MoveStatus(done=True, pos=bender_um, elapsed=8.4, success=True, settle_time=0.0)

# %%
print(mono_energy.get())
print(Obender.get())
print(bcs_linear_motor.get())
# Out:
# MonoEnergyTuple(energy_eV=PseudoSingleTuple(readback=np.float64(8000.184027806925), setpoint=8000), mono_angle=EpicsMotorTuple(user_readback=20.755, user_setpoint=20.755336204715938, user_offset=0.0, user_offset_dir=0, offset_freeze_switch=0, set_use_switch=0, velocity=1.0, acceleration=0.2, motor_egu='deg', motor_is_moving=0, motor_done_move=1, high_limit_switch=0, low_limit_switch=0, high_limit_travel=180.0, low_limit_travel=-100.0, direction_of_travel=0, motor_stop=0, home_forward=0, home_reverse=0), offset=np.float64(6.444797761216426))
# EpicsMotorTuple(user_readback=-1999.98786, user_setpoint=-2000.0, user_offset=0.0, user_offset_dir=0, offset_freeze_switch=0, set_use_switch=0, velocity=100.0, acceleration=0.2, motor_egu='um', motor_is_moving=0, motor_done_move=1, high_limit_switch=0, low_limit_switch=0, high_limit_travel=5000.0, low_limit_travel=-2000.0, direction_of_travel=1, motor_stop=0, home_forward=0, home_reverse=0)
# 4.399955

# %% [markdown]
# ### Chip translation scan

# %%
uid_03 = RE(bp.scan([basler_5472], bcs_linear_motor, 4.400, 4.410, 11))
# Out:
# Transient Scan ID: 7     Time: 2026-05-29 18:19:20
# Persistent Unique Scan ID: '268cc8d5-17a6-48ae-9ead-f10401781559'
# New stream: 'baseline'
# Start-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8000.184027806925              |
# |         mono_energy_mono_angle | 20.755                         |
# |                      bender_um | -1999.98786                    |
# |               bcs_linear_motor | 4.399955                       |
# +--------------------------------+--------------------------------+
# New stream: 'primary'
# +-----------+------------+------------------+
# |   seq_num |       time | bcs_linear_motor |
# +-----------+------------+------------------+
# |         1 | 18:19:25.6 |            4.400 |
# |         2 | 18:19:31.1 |            4.401 |
# |         3 | 18:19:37.4 |            4.402 |
# |         4 | 18:19:42.8 |            4.403 |
# |         5 | 18:19:48.1 |            4.404 |
# |         6 | 18:19:53.4 |            4.405 |
# |         7 | 18:19:58.8 |            4.406 |
# |         8 | 18:20:04.2 |            4.407 |
# |         9 | 18:20:09.6 |            4.408 |
# |        10 | 18:20:14.9 |            4.409 |
# |        11 | 18:20:20.3 |            4.410 |
# +-----------+------------+------------------+
# generator scan ['268cc8d5'] (scan num: 7)
# End-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8000.184027806925              |
# |         mono_energy_mono_angle | 20.755                         |
# |                      bender_um | -1999.98786                    |
# |               bcs_linear_motor | 4.409976                       |
# +--------------------------------+--------------------------------+

# %%
db = tiled_client[uid_03]

# Metadata
# wfs_chip_pos_mm = db['baseline']['bcs_linear_motor'].read()
bender_um = db['baseline']['bender_um'].read()
energy_eV = db['baseline']['mono_energy_energy_eV'].read()

# print(f"WFS chip position (mm): {wfs_chip_pos_mm}")
print(f"Mono energy (eV): {energy_eV}")
print(f"Bender position (µm): {bender_um}")

# Data arrays (slow)
images    = db['primary']['basler_5472_image'].read()  
wfs_chip_pos_mm = db['primary']['bcs_linear_motor'].read()   
# energy_eV = db['primary']['mono_energy_energy_eV'].read() 
# bender_um = db['primary']['bender_um'].read() 

# Print summaries
print(f"\nImages shape: {images.shape}  (n_frames × height × width)")
# print(f"Energy range: {energy_eV.min():.1f} – {energy_eV.max():.1f} eV")
# print(f"       shape: {energy_eV.shape}")
# print(f"Bender range: {bender_um.min():.1f} – {bender_um.max():.1f} µm")
# print(f"       shape: {bender_um.shape}")
print(f"WFS chip position range: {wfs_chip_pos_mm.min():.3f} – {wfs_chip_pos_mm.max():.3f} mm")
print(f"       shape: {wfs_chip_pos_mm.shape}")
# Out:
# Mono energy (eV): [8000.18402781 8000.18402781]
# Bender position (µm): [-1999.98786 -1999.98786]
#
# Images shape: (11, 2900, 1100)  (n_frames × height × width)
# WFS chip position range: 4.400 – 4.410 mm
#        shape: (11,)

# %%
idx = 10

plt.figure(figsize=(8, 3))
plt.imshow(images[idx].T, cmap='hot', interpolation='nearest', vmax=4000)
plt.title(f'idx={idx}   E={energy_eV[0]:.0f} eV   bender={bender_um[0]:.0f} µm   chip_pos={wfs_chip_pos_mm[idx]:.3f} mm', fontsize=12)
plt.xlabel('y [pixels]')
plt.ylabel('x [pixels]')
plt.colorbar(label='Intensity [counts]')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Grid scan

# %%
from bluesky.plans import grid_scan

print(f"Energy setpoint: {mono_energy.get().energy_eV.setpoint:.1f} eV (readback: {mono_energy.get().energy_eV.setpoint:.1f} eV)")
print(f"Bender setpoint: {Obender.get().user_setpoint:.0f} µm (readback: {Obender.get().user_readback:.0f} µm)")
print(f"BCS linear motor: {bcs_linear_motor.get():.3f} mm")

uid_04 = RE(grid_scan([basler_5472], mono_energy, 7500, 8500, 3, Obender, -2000, -1400, 4, snake_axes=False, md=md))
# Out:
# Energy setpoint: 8000.0 eV (readback: 8000.0 eV)
# Bender setpoint: -2000 µm (readback: -2000 µm)
# BCS linear motor: 4.410 mm
#
#
# Transient Scan ID: 8     Time: 2026-05-29 18:31:41
# Persistent Unique Scan ID: '19792fc0-a08c-46d6-89a4-a7a2cd138c5d'
# New stream: 'baseline'
# Start-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8000.184027806925              |
# |         mono_energy_mono_angle | 20.755                         |
# |                      bender_um | -1999.98786                    |
# |               bcs_linear_motor | 4.409976                       |
# +--------------------------------+--------------------------------+
# New stream: 'primary'
# +-----------+------------+-----------------------+------------------------+------------+
# |   seq_num |       time | mono_energy_energy_eV | mono_energy_mono_angle |  bender_um |
# +-----------+------------+-----------------------+------------------------+------------+
# |         1 | 18:31:46.9 |              7499.947 |                21.7320 | -1999.98786 |
# |         2 | 18:31:54.4 |              7499.947 |                21.7320 | -1800.02151 |
# |         3 | 18:32:01.6 |              7499.947 |                21.7320 | -1600.01859 |
# |         4 | 18:32:08.9 |              7499.947 |                21.7320 | -1400.01726 |
# |         5 | 18:32:20.2 |              8000.184 |                20.7550 | -1999.98786 |
# |         6 | 18:32:27.5 |              8000.184 |                20.7550 | -1800.01992 |
# |         7 | 18:32:34.8 |              8000.184 |                20.7550 | -1600.01859 |
# |         8 | 18:32:42.0 |              8000.184 |                20.7550 | -1400.01726 |
# |         9 | 18:32:53.4 |              8500.121 |                19.8970 | -1999.98786 |
# |        10 | 18:33:00.7 |              8500.121 |                19.8970 | -1800.01992 |
# |        11 | 18:33:07.9 |              8500.121 |                19.8970 | -1600.01859 |
# |        12 | 18:33:15.2 |              8500.121 |                19.8970 | -1400.01726 |
# +-----------+------------+-----------------------+------------------------+------------+
# generator grid_scan ['19792fc0'] (scan num: 8)
# End-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8500.120512345971              |
# |         mono_energy_mono_angle | 19.897000000000002             |
# |                      bender_um | -1400.01726                    |
# |               bcs_linear_motor | 4.409976                       |
# +--------------------------------+--------------------------------+

# %%
db = tiled_client[uid_04]

# Metadata
wfs_chip_pos_mm = db['baseline']['bcs_linear_motor'].read()
# bender_um = db['baseline']['bender_um'].read()
# energy_eV = db['baseline']['mono_energy_energy_eV'].read()

print(f"WFS chip position (mm): {wfs_chip_pos_mm}")
# print(f"Mono energy (eV): {energy_eV}")
# print(f"Bender position (µm): {bender_um}")

# Data arrays (slow)
images    = db['primary']['basler_5472_image'].read()  
# wfs_chip_pos_mm = db['primary']['bcs_linear_motor'].read()   
energy_eV = db['primary']['mono_energy_energy_eV'].read() 
bender_um = db['primary']['bender_um'].read() 

# Print summaries
print(f"\nImages shape: {images.shape}  (n_frames × height × width)")
print(f"Energy range: {energy_eV.min():.1f} – {energy_eV.max():.1f} eV")
print(f"       shape: {energy_eV.shape}")
print(f"Bender range: {bender_um.min():.1f} – {bender_um.max():.1f} µm")
print(f"       shape: {bender_um.shape}")
# print(f"WFS chip position range: {wfs_chip_pos_mm.min():.3f} – {wfs_chip_pos_mm.max():.3f} mm")
# print(f"       shape: {wfs_chip_pos_mm.shape}")
# Out:
# WFS chip position (mm): [4.409976 4.409976]
#
# Images shape: (12, 2900, 1100)  (n_frames × height × width)
# Energy range: 7499.9 – 8500.1 eV
#        shape: (12,)
# Bender range: -2000.0 – -1400.0 µm
#        shape: (12,)

# %%
idx = 11

plt.figure(figsize=(8, 3))
plt.imshow(images[idx].T, cmap='hot', interpolation='nearest', vmax=4000)
plt.title(f'idx={idx}   E={energy_eV[idx]:.0f} eV   bender={bender_um[idx]:.0f} µm   chip_pos={wfs_chip_pos_mm[0]:.3f} mm', fontsize=12)
plt.xlabel('y [pixels]')
plt.ylabel('x [pixels]')
plt.colorbar(label='Intensity [counts]')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Measurements

# %%
from bluesky.plans import grid_scan

mono_energy.move(8000)
Obender.move(-2000)

print(f"Energy setpoint: {mono_energy.get().energy_eV.setpoint:.1f} eV (readback: {mono_energy.get().energy_eV.setpoint:.1f} eV)")
print(f"Bender setpoint: {Obender.get().user_setpoint:.0f} µm (readback: {Obender.get().user_readback:.0f} µm)")
print(f"BCS linear motor: {bcs_linear_motor.get():.3f} mm")

uid_05 = RE(grid_scan([basler_5472], mono_energy, 7000, 9000, 11, Obender, -2000, -1400, 13, snake_axes=False, md=md))
# Out:
# Energy setpoint: 8000.0 eV (readback: 8000.0 eV)
# Bender setpoint: -2000 µm (readback: -2000 µm)
# BCS linear motor: 4.410 mm
#
#
# Transient Scan ID: 9     Time: 2026-05-29 18:39:05
# Persistent Unique Scan ID: '4adb81df-534d-4fc9-8590-ab1a449e5b54'
# New stream: 'baseline'
# Start-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 
# |        33 | 18:42:27.2 |              7399.825 |                21.9440 | -1700.02005 |
# |        34 | 18:42:33.0 |              7399.825 |                21.9440 | -1650.01932 |
# |        35 | 18:42:38.9 |              7399.825 |                21.9440 | -1600.01700 |
# |        36 | 18:42:44.6 |              7399.825 |                21.9440 | -1550.01786 |
# |        37 | 18:42:50.3 |              7399.825 |                21.9440 | -1500.01713 |
# |        38 | 18:42:56.1 |              7399.825 |                21.9440 | -1450.01958 |
# |        39 | 18:43:01.9 |              7399.825 |                21.9440 | -1400.01726 |
# |        40 | 18:43:13.3 |              7599.966 |                21.5260 | -1999.98786 |
# |        41 | 18:43:19.1 |              7599.966 |                21.5260 | -1950.02052 |
# |        42 | 18:43:25.0 |              7599.966 |                21.5260 | -1900.01820 |
# |        43 | 18:43:30.8 |              7599.966 |                21.5260 | -1850.01906 |
# |        44 | 18:43:36.6 |              7599.966 |                21.5260 | -1800.01992 |
# |        45 | 18:43:42.4 |              7599.966 |                21.5260 | -1750.01919 |
# |        46 | 18:43:48.1 |              7599.966 |                21.5260 | -1700.02005 |
# |        47 | 18:43:53.8 |              7599.966 |                21.5260 | -1650.01932 |
# |        48 | 18:43:59.6 |              7599.966 |                21.5260 | -1600.01859 |
# |        49 | 18:44:05.4 |              7599.966 |                21.5260 | -1550.01945 |
# +-----------+------------+-----------------------+------------------------+------------+
# |   seq_num |       time | mono_energy_energy_eV | mono_energy_mono_angle |  bender_um |
# +-----------+------------+-----------------------+------------------------+------------+
# |        50 | 18:44:11.2 |              7599.966 |                21.5260 | -1500.01872 |
# |        51 | 18:44:17.0 |              7599.966 |                21.5260 | -1450.01958 |
# |        52 | 18:44:22.8 |              7599.966 |                21.5260 | -1400.01726 |
# |        53 | 18:44:34.3 |              7799.696 |                21.1310 | -1999.98627 |
# |        54 | 18:44:40.2 |              7799.696 |                21.1310 | -1950.02052 |
# |        55 | 18:44:45.9 |              7799.696 |                21.1310 | -1900.01820 |
# |        56 | 18:44:51.7 |              7799.696 |                21.1310 | -1850.01906 |
# |        57 | 18:44:57.5 |              7799.696 |                21.1310 | -1800.01992 |
# |        58 | 18:45:03.4 |              7799.696 |                21.1310 | -1750.01760 |
# |        59 | 18:45:09.1 |              7799.696 |                21.1310 | -1700.02005 |
# |        60 | 18:45:15.0 |              7799.696 |                21.1310 | -1650.01773 |
# |        61 | 18:45:20.9 |              7799.696 |                21.1310 | -1600.01859 |
# |        62 | 18:45:26.8 |              7799.696 |                21.1310 | -1550.01786 |
# |        63 | 18:45:32.7 |              7799.696 |                21.1310 | -1500.01872 |
# |        64 | 18:45:38.5 |              7799.696 |                21.1310 | -1450.01799 |
# |        65 | 18:45:44.3 |              7799.696 |                21.1310 | -1400.01726 |
# |        66 | 18:45:55.7 |              8000.184 |                20.7550 | -1999.98786 |
# |        67 | 18:46:01.5 |              8000.184 |                20.7550 | -1950.02052 |
# |        68 | 18:46:07.3 |              8000.184 |                20.7550 | -1900.01820 |
# |        69 | 18:46:13.2 |              8000.184 |                20.7550 | -1850.01906 |
of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8999.986357882728              |
# |         mono_energy_mono_angle | 19.137                         |
# |                      bender_um | -1400.01726                    |
# |               bcs_linear_motor | 4.409976                       |
# +--------------------------------+--------------------------------+

# %%
db = tiled_client[uid_05]

# Metadata
wfs_chip_pos_mm = db['baseline']['bcs_linear_motor'].read()
# bender_um = db['baseline']['bender_um'].read()
# energy_eV = db['baseline']['mono_energy_energy_eV'].read()

print(f"WFS chip position (mm): {wfs_chip_pos_mm}")
# print(f"Mono energy (eV): {energy_eV}")
# print(f"Bender position (µm): {bender_um}")

# Data arrays (slow)
images    = db['primary']['basler_5472_image'].read()  
# wfs_chip_pos_mm = db['primary']['bcs_linear_motor'].read()   
energy_eV = db['primary']['mono_energy_energy_eV'].read() 
bender_um = db['primary']['bender_um'].read() 

# Print summaries
print(f"\nImages shape: {images.shape}  (n_frames × height × width)")
print(f"Energy range: {energy_eV.min():.1f} – {energy_eV.max():.1f} eV")
print(f"       shape: {energy_eV.shape}")
print(f"Bender range: {bender_um.min():.1f} – {bender_um.max():.1f} µm")
print(f"       shape: {bender_um.shape}")
# print(f"WFS chip position range: {wfs_chip_pos_mm.min():.3f} – {wfs_chip_pos_mm.max():.3f} mm")
# print(f"       shape: {wfs_chip_pos_mm.shape}")
# Out:
# WFS chip position (mm): [4.409976 4.409976]
#
# Images shape: (143, 2900, 1100)  (n_frames × height × width)
# Energy range: 6999.8 – 9000.0 eV
#        shape: (143,)
# Bender range: -2000.0 – -1400.0 µm
#        shape: (143,)

# %%
idx = 131

plt.figure(figsize=(8, 3))
plt.imshow(images[idx].T, cmap='hot', interpolation='nearest', vmax=4000)
plt.title(f'idx={idx}   E={energy_eV[idx]:.0f} eV   bender={bender_um[idx]:.0f} µm   chip_pos={wfs_chip_pos_mm[0]:.3f} mm', fontsize=12)
plt.xlabel('y [pixels]')
plt.ylabel('x [pixels]')
plt.colorbar(label='Intensity [counts]')
plt.tight_layout()
plt.show()

# %%
mono_energy.move(8000)
Obender.move(-2000)
# Out:
# MoveStatus(done=True, pos=bender_um, elapsed=8.4, success=True, settle_time=0.0)

# %%
from bluesky.plans import grid_scan

print(f"Energy setpoint: {mono_energy.get().energy_eV.setpoint:.1f} eV (readback: {mono_energy.get().energy_eV.setpoint:.1f} eV)")
print(f"Bender setpoint: {Obender.get().user_setpoint:.0f} µm (readback: {Obender.get().user_readback:.0f} µm)")
print(f"BCS linear motor: {bcs_linear_motor.get():.3f} mm")

uid_06 = RE(grid_scan([basler_5472], mono_energy, 7000, 9000, 11, Obender, -400, 0, 9, snake_axes=False, md=md))
# Out:
# Energy setpoint: 8000.0 eV (readback: 8000.0 eV)
# Bender setpoint: -2000 µm (readback: -2000 µm)
# BCS linear motor: 4.410 mm
#
#
# Transient Scan ID: 10     Time: 2026-05-29 20:54:17
# Persistent Unique Scan ID: 'f87cf0d3-ab99-464b-81fa-73d9d892f374'
# New stream: 'baseline'
# Start-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 
# |        76 | 21:02:21.5 |              8599.927 |                19.7380 | -250.01319 |
# |        77 | 21:02:27.4 |              8599.927 |                19.7380 | -200.01246 |
# |        78 | 21:02:33.3 |              8599.927 |                19.7380 | -150.01173 |
# |        79 | 21:02:39.1 |              8599.927 |                19.7380 | -100.01100 |
# |        80 | 21:02:45.0 |              8599.927 |                19.7380 |  -50.01345 |
# |        81 | 21:02:50.9 |              8599.927 |                19.7380 |   -0.01113 |
# |        82 | 21:03:00.3 |              8800.281 |                19.4300 | -399.99471 |
# |        83 | 21:03:06.1 |              8800.281 |                19.4300 | -350.01306 |
# |        84 | 21:03:12.0 |              8800.281 |                19.4300 | -300.01233 |
# |        85 | 21:03:17.8 |              8800.281 |                19.4300 | -250.01319 |
# |        86 | 21:03:23.5 |              8800.281 |                19.4300 | -200.01246 |
# |        87 | 21:03:29.4 |              8800.281 |                19.4300 | -150.01173 |
# |        88 | 21:03:35.2 |              8800.281 |                19.4300 | -100.01100 |
# |        89 | 21:03:41.0 |              8800.281 |                19.4300 |  -50.01345 |
# |        90 | 21:03:46.9 |              8800.281 |                19.4300 |   -0.01113 |
# |        91 | 21:03:56.3 |              8999.986 |                19.1370 | -399.99312 |
# |        92 | 21:04:02.2 |              8999.986 |                19.1370 | -350.01465 |
# |        93 | 21:04:07.9 |              8999.986 |                19.1370 | -300.01233 |
# |        94 | 21:04:13.7 |              8999.986 |                19.1370 | -250.01319 |
# |        95 | 21:04:19.6 |              8999.986 |                19.1370 | -200.01246 |
# |        96 | 21:04:25.4 |              8999.986 |                19.1370 | -150.01173 |
# |        97 | 21:04:31.4 |              8999.986 |                19.1370 | -100.01100 |
# |        98 | 21:04:37.2 |              8999.986 |                19.1370 |  -50.01345 |
# |        99 | 21:04:43.1 |              8999.986 |                19.1370 |   -0.01113 |
# +-----------+------------+-----------------------+------------------------+------------+
# generator grid_scan ['f87cf0d3'] (scan num: 10)
# End-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8999.986357882728              |
# |         mono_energy_mono_angle | 19.137                         |
# |                      bender_um | -0.011130000000000001          |
# |               bcs_linear_motor | 4.409976                       |
# +--------------------------------+--------------------------------+

# %%
db = tiled_client[uid_06]

# Metadata
wfs_chip_pos_mm = db['baseline']['bcs_linear_motor'].read()
# bender_um = db['baseline']['bender_um'].read()
# energy_eV = db['baseline']['mono_energy_energy_eV'].read()

print(f"WFS chip position (mm): {wfs_chip_pos_mm}")
# print(f"Mono energy (eV): {energy_eV}")
# print(f"Bender position (µm): {bender_um}")

# Data arrays (slow)
images    = db['primary']['basler_5472_image'].read()  
# wfs_chip_pos_mm = db['primary']['bcs_linear_motor'].read()   
energy_eV = db['primary']['mono_energy_energy_eV'].read() 
bender_um = db['primary']['bender_um'].read() 

# Print summaries
print(f"\nImages shape: {images.shape}  (n_frames × height × width)")
print(f"Energy range: {energy_eV.min():.1f} – {energy_eV.max():.1f} eV")
print(f"       shape: {energy_eV.shape}")
print(f"Bender range: {bender_um.min():.1f} – {bender_um.max():.1f} µm")
print(f"       shape: {bender_um.shape}")
# print(f"WFS chip position range: {wfs_chip_pos_mm.min():.3f} – {wfs_chip_pos_mm.max():.3f} mm")
# print(f"       shape: {wfs_chip_pos_mm.shape}")
# Out:
# WFS chip position (mm): [4.409976 4.409976]
#
# Images shape: (99, 2900, 1100)  (n_frames × height × width)
# Energy range: 6999.8 – 9000.0 eV
#        shape: (99,)
# Bender range: -400.0 – -0.0 µm
#        shape: (99,)

# %%
mono_energy.move(8000)
Obender.move(-2000)

print(f"Energy setpoint: {mono_energy.get().energy_eV.setpoint:.1f} eV (readback: {mono_energy.get().energy_eV.setpoint:.1f} eV)")
print(f"Bender setpoint: {Obender.get().user_setpoint:.0f} µm (readback: {Obender.get().user_readback:.0f} µm)")
print(f"BCS linear motor: {bcs_linear_motor.get():.3f} mm")

uid_07 = RE(bp.scan([basler_5472], bcs_linear_motor, 4.410, 4.600, 191))

uid_08 = RE(bp.scan([basler_5472], bcs_linear_motor, 5.500, 5.700, 201))
# Out:
# Energy setpoint: 8000.0 eV (readback: 8000.0 eV)
# Bender setpoint: -2000 µm (readback: -2000 µm)
# BCS linear motor: 4.410 mm
#
#
# Transient Scan ID: 11     Time: 2026-05-29 21:11:25
# Persistent Unique Scan ID: 'a9a6beac-9762-4cfb-939f-d5d18beb9541'
# New stream: 'baseline'
# Start-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8000.184027806925              |
# |         mono_energy_mono_angle | 20.755                         |
# |                      bender_um | -1999.98627                    |
# |               bcs_linear_motor | 4.409976                       |
# +--------------------------------+--------------------------------+
# New stream: 'primary'
# +-----------+------------+------------------+
# |   seq_num |       time | bcs_linear_motor |
# +-----------+------------+------------------+
# |         1 | 21:11:30.7 |            4.410 |
# |         2 | 21:11:36.2 |            4.411 |
# |         3 | 21:11:41.5 |            4.412 |
# |         4 | 21:11:46.9 |            4.413 |
# |         5 | 21:11:52.2 |            4.414 |
# |         6 | 21:11:57.6 |            4.415 |
# |         7 | 21:12:02.9 |            4.416 |
# |         8 | 21:12:08.3 |            4.417 |
# |         9 | 21:12:13.7 |            4.418 |
# |        10 | 21:12:19.1 |            4.419 |
# |        11 | 21:12:24.4 |            4.420 |
# |        12 | 21:12:29.8 |            4.421 |
# |        13 | 21:12:35.2 |            4.422 |
# |        14 | 21:12:40.6 |            4.423 |
# |        15 | 21:12:45.9 |            4.424 |
# |        16 | 21:12:51.3 |            4.425 |
# |        17 | 21:12:56.7 |            4.426 |
# |        18 | 21:13:02.1 |            4.427 |
# |        19 | 21:13:07.4 |            4.428 |
# |        20 | 21:13:12.8 |            4.429 |
# |        21 | 21:13:18.2 |            4.430 |
# |        22 | 21:13:23.6 |            4.431 |
# |        23 | 21:13:29.0 |            4.432 |
# |        24 | 21:13:34.4 |            4.433 |
# |        25 | 21:13:39.8 |            4.434 |
# |        26 | 21:13:45.1 |            4.435 |
# |        27 | 21:13:50.6 |            4.436 |
# |        28 | 21:13:55.9 |            4.437 |
# |        29 | 21:14:01.4 |            4.438 |
# |        30 | 21:14:06.8 |            4.439 |
# |        31 | 21:14:12.2 |            4.440 |
# |        32 | 21:14:17.6 |            4.441 |
# |        33 | 21:14:23.0 |            4.442 |
# |       161 | 21:26:08.9 |            4.570 |
# |       162 | 21:26:14.5 |            4.571 |
# |       163 | 21:26:20.1 |            4.572 |
# |       164 | 21:26:25.7 |            4.573 |
# |       165 | 21:26:31.3 |            4.574 |
# |       166 | 21:26:36.9 |            4.575 |
# |       167 | 21:26:42.5 |            4.576 |
# |       168 | 21:26:48.1 |            4.577 |
# |       169 | 21:26:53.7 |            4.578 |
# |       170 | 21:26:59.3 |            4.579 |
# |       171 | 21:27:05.0 |            4.580 |
# |       172 | 21:27:10.6 |            4.581 |
# |       173 | 21:27:16.2 |            4.582 |
# |       174 | 21:27:21.8 |            4.583 |
# |       175 | 21:27:27.4 |            4.584 |
# |       176 | 21:27:33.0 |            4.585 |
# |       177 | 21:27:38.6 |            4.586 |
# |       178 | 21:27:44.2 |            4.587 |
# |       179 | 21:27:49.8 |            4.588 |
# |       180 | 21:27:55.5 |            4.589 |
# |       181 | 21:28:01.1 |            4.590 |
# |       182 | 21:28:06.7 |            4.591 |
# |       183 | 21:28:12.3 |            4.592 |
# |       184 | 21:28:18.0 |            4.593 |
# |       185 | 21:28:23.6 |            4.594 |
# |       186 | 21:28:29.2 |            4.595 |
# |       187 | 21:28:34.8 |            4.596 |
# |       188 | 21:28:40.4 |            4.597 |
# |       189 | 21:28:46.0 |            4.598 |
# |       190 | 21:28:51.8 |            4.599 |
# |       191 | 21:28:57.4 |            4.600 |
# +-----------+------------+------------------+
# generator scan ['a9a6beac'] (scan num: 11)
# End-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8000.184027806925              |
# |         mono_energy_mono_angle | 20.755                         |
# |                      bender_um | -1999.98627                    |
# |               bcs_linear_motor | 4.59998                        |
# +--------------------------------+--------------------------------+
#
#
#
#
#
# Transient Scan ID: 12     Time: 2026-05-29 21:28:58
# Persistent Unique Scan ID: 'ce368e98-65b2-4059-a954-2a2d05c21dbc'
# New stream: 'baseline'
# Start-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8000.184027806925              |
# |         mono_energy_mono_angle | 20.755                         |
# |                      bender_um | -1999.98627                    |
# |               bcs_linear_motor | 4.59998                        |
# +--------------------------------+--------------------------------+
# New stream: 'primary'
# +-----------+------------+------------------+
# |   seq_num |       time | bcs_linear_motor |
# +-----------+------------+------------------+
# |         1 | 21:29:04.5 |            5.500 |
# |         2 | 21:29:10.0 |            5.501 |
# |         3 | 21:29:15.3 |            5.502 |
# |         4 | 21:29:20.7 |            5.503 |
# |         5 | 21:29:26.0 |            5.504 |
# |         6 | 21:29:31.4 |            5.505 |
# |         7 | 21:29:36.8 |            5.506 |
# |         8 | 21:29:42.2 |            5.507 |
# |         9 | 21:29:47.5 |            5.508 |
# |        10 | 21:29:52.9 |            5.509 |
# |        11 | 21:29:58.3 |            5.510 |
# |        12 | 21:30:03.7 |            5.511 |
# |        13 | 21:30:09.0 |            5.512 |
# |        14 | 21:30:14.4 |            5.513 |
# |        15 | 21:30:19.8 |            5.514 |
# |        16 | 21:30:25.1 |            5.515 |
# |        17 | 21:30:30.5 |            5.516 |
# |        18 | 21:30:35.9 |            5.517 |
of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8000.184027806925              |
# |         mono_energy_mono_angle | 20.755                         |
# |                      bender_um | -1999.98627                    |
# |               bcs_linear_motor | 5.700018                       |
# +--------------------------------+--------------------------------+

# %%
db = tiled_client[uid_07]

# Metadata
# wfs_chip_pos_mm = db['baseline']['bcs_linear_motor'].read()
bender_um = db['baseline']['bender_um'].read()
energy_eV = db['baseline']['mono_energy_energy_eV'].read()

# print(f"WFS chip position (mm): {wfs_chip_pos_mm}")
print(f"Mono energy (eV): {energy_eV}")
print(f"Bender position (µm): {bender_um}")

# Data arrays (slow)
images    = db['primary']['basler_5472_image'].read()  
wfs_chip_pos_mm = db['primary']['bcs_linear_motor'].read()   
# energy_eV = db['primary']['mono_energy_energy_eV'].read() 
# bender_um = db['primary']['bender_um'].read() 

# Print summaries
print(f"\nImages shape: {images.shape}  (n_frames × height × width)")
# print(f"Energy range: {energy_eV.min():.1f} – {energy_eV.max():.1f} eV")
# print(f"       shape: {energy_eV.shape}")
# print(f"Bender range: {bender_um.min():.1f} – {bender_um.max():.1f} µm")
# print(f"       shape: {bender_um.shape}")
print(f"WFS chip position range: {wfs_chip_pos_mm.min():.3f} – {wfs_chip_pos_mm.max():.3f} mm")
print(f"       shape: {wfs_chip_pos_mm.shape}")
# Out:
# Mono energy (eV): [8000.18402781 8000.18402781]
# Bender position (µm): [-1999.98627 -1999.98627]
#
# Images shape: (191, 2900, 1100)  (n_frames × height × width)
# WFS chip position range: 4.410 – 4.600 mm
#        shape: (191,)

# %%
idx = 190

plt.figure(figsize=(8, 3))
plt.imshow(images[idx].T, cmap='hot', interpolation='nearest', vmax=4000)
plt.title(f'idx={idx}   E={energy_eV[0]:.0f} eV   bender={bender_um[0]:.0f} µm   chip_pos={wfs_chip_pos_mm[idx]:.3f} mm', fontsize=12)
plt.xlabel('y [pixels]')
plt.ylabel('x [pixels]')
plt.colorbar(label='Intensity [counts]')
plt.tight_layout()
plt.show()

# %%
uid_09 = RE(bp.count([basler_5472], num=1, md = md))
# Out:
# Transient Scan ID: 13     Time: 2026-05-29 22:36:26
# Persistent Unique Scan ID: 'f8d40046-cb42-493f-bbe6-503eeec51556'
# New stream: 'baseline'
# Start-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8000.184027806925              |
# |         mono_energy_mono_angle | 20.755                         |
# |                      bender_um | -1999.98627                    |
# |               bcs_linear_motor | 5.700018                       |
# +--------------------------------+--------------------------------+
# New stream: 'primary'
# +-----------+------------+
# |   seq_num |       time |
# +-----------+------------+
# |         1 | 22:36:29.5 |
# +-----------+------------+
# generator count ['f8d40046'] (scan num: 13)
# End-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8000.184027806925              |
# |         mono_energy_mono_angle | 20.755                         |
# |                      bender_um | -1999.98627                    |
# |               bcs_linear_motor | 5.700018                       |
# +--------------------------------+--------------------------------+

# %%
db = tiled_client[uid_09]

# Metadata
wfs_chip_pos_mm = db['baseline']['bcs_linear_motor'].read()
bender_um = db['baseline']['bender_um'].read()
energy_eV = db['baseline']['mono_energy_energy_eV'].read()

print(f"WFS chip position (mm): {wfs_chip_pos_mm}")
print(f"Mono energy (eV): {energy_eV}")
print(f"Bender position (µm): {bender_um}")

# Data arrays (slow)
images    = db['primary']['basler_5472_image'].read()  
# wfs_chip_pos_mm = db['primary']['bcs_linear_motor'].read()   
# energy_eV = db['primary']['mono_energy_energy_eV'].read() 
# bender_um = db['primary']['bender_um'].read() 

# Print summaries
print(f"\nImages shape: {images.shape}  (n_frames × height × width)")
# print(f"Energy range: {energy_eV.min():.1f} – {energy_eV.max():.1f} eV")
# print(f"       shape: {energy_eV.shape}")
# print(f"Bender range: {bender_um.min():.1f} – {bender_um.max():.1f} µm")
# print(f"       shape: {bender_um.shape}")
# print(f"WFS chip position range: {wfs_chip_pos_mm.min():.3f} – {wfs_chip_pos_mm.max():.3f} mm")
# print(f"       shape: {wfs_chip_pos_mm.shape}")
# Out:
# WFS chip position (mm): [5.700018 5.700018]
# Mono energy (eV): [8000.18402781 8000.18402781]
# Bender position (µm): [-1999.98627 -1999.98627]
#
# Images shape: (1, 2900, 1100)  (n_frames × height × width)

# %%
plt.figure(figsize=(8, 3))
plt.imshow(images[0].T, cmap='hot', interpolation='nearest', vmax=4000)
plt.title(f'idx=0   E={energy_eV[0]:.0f} eV   bender={bender_um[0]:.0f} µm   chip_pos={wfs_chip_pos_mm[0]:.3f} mm', fontsize=12)
plt.xlabel('y [pixels]')
plt.ylabel('x [pixels]')
plt.colorbar(label='Intensity [counts]')
plt.tight_layout()
plt.show()

# %%
mono_energy.move(8000)
Obender.move(-2000)

print(f"Energy setpoint: {mono_energy.get().energy_eV.setpoint:.1f} eV (readback: {mono_energy.get().energy_eV.setpoint:.1f} eV)")
print(f"Bender setpoint: {Obender.get().user_setpoint:.0f} µm (readback: {Obender.get().user_readback:.0f} µm)")
print(f"BCS linear motor: {bcs_linear_motor.get():.3f} mm")

uid_10 = RE(bp.scan([basler_5472], bcs_linear_motor, 7.400, 7.410, 2))
# Out:
# Energy setpoint: 8000.0 eV (readback: 8000.0 eV)
# Bender setpoint: -2000 µm (readback: -2000 µm)
# BCS linear motor: 5.700 mm
#
#
# Transient Scan ID: 14     Time: 2026-05-29 22:41:47
# Persistent Unique Scan ID: 'c5848321-91bb-41bf-a0a0-577a2a4ab91f'
# New stream: 'baseline'
# Start-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8000.184027806925              |
# |         mono_energy_mono_angle | 20.755                         |
# |                      bender_um | -1999.98786                    |
# |               bcs_linear_motor | 5.700018                       |
# +--------------------------------+--------------------------------+
# New stream: 'primary'
# +-----------+------------+------------------+
# |   seq_num |       time | bcs_linear_motor |
# +-----------+------------+------------------+
# |         1 | 22:41:52.9 |            7.400 |
# |         2 | 22:41:58.3 |            7.410 |
# +-----------+------------+------------------+
# generator scan ['c5848321'] (scan num: 14)
# End-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8000.184027806925              |
# |         mono_energy_mono_angle | 20.755                         |
# |                      bender_um | -1999.98786                    |
# |               bcs_linear_motor | 7.409954                       |
# +--------------------------------+--------------------------------+

# %%
db = tiled_client[uid_10]

# Metadata
# wfs_chip_pos_mm = db['baseline']['bcs_linear_motor'].read()
bender_um = db['baseline']['bender_um'].read()
energy_eV = db['baseline']['mono_energy_energy_eV'].read()

# print(f"WFS chip position (mm): {wfs_chip_pos_mm}")
print(f"Mono energy (eV): {energy_eV}")
print(f"Bender position (µm): {bender_um}")

# Data arrays (slow)
images    = db['primary']['basler_5472_image'].read()  
wfs_chip_pos_mm = db['primary']['bcs_linear_motor'].read()   
# energy_eV = db['primary']['mono_energy_energy_eV'].read() 
# bender_um = db['primary']['bender_um'].read() 

# Print summaries
print(f"\nImages shape: {images.shape}  (n_frames × height × width)")
# print(f"Energy range: {energy_eV.min():.1f} – {energy_eV.max():.1f} eV")
# print(f"       shape: {energy_eV.shape}")
# print(f"Bender range: {bender_um.min():.1f} – {bender_um.max():.1f} µm")
# print(f"       shape: {bender_um.shape}")
print(f"WFS chip position range: {wfs_chip_pos_mm.min():.3f} – {wfs_chip_pos_mm.max():.3f} mm")
print(f"       shape: {wfs_chip_pos_mm.shape}")
# Out:
# Mono energy (eV): [8000.18402781 8000.18402781]
# Bender position (µm): [-1999.98786 -1999.98786]
#
# Images shape: (2, 2900, 1100)  (n_frames × height × width)
# WFS chip position range: 7.400 – 7.410 mm
#        shape: (2,)

# %%
plt.figure(figsize=(8, 3))
plt.imshow(images[0].T, cmap='hot', interpolation='nearest', vmax=4000)
plt.title(f'idx=0   E={energy_eV[0]:.0f} eV   bender={bender_um[0]:.0f} µm   chip_pos={wfs_chip_pos_mm[0]:.3f} mm', fontsize=12)
plt.xlabel('y [pixels]')
plt.ylabel('x [pixels]')
plt.colorbar(label='Intensity [counts]')
plt.tight_layout()
plt.show()

# %%
from bluesky.plans import grid_scan

mono_energy.move(8000)
Obender.move(-2000)

print(f"Energy setpoint: {mono_energy.get().energy_eV.setpoint:.1f} eV (readback: {mono_energy.get().energy_eV.setpoint:.1f} eV)")
print(f"Bender setpoint: {Obender.get().user_setpoint:.0f} µm (readback: {Obender.get().user_readback:.0f} µm)")
print(f"BCS linear motor: {bcs_linear_motor.get():.3f} mm")

uid_11 = RE(grid_scan([basler_5472], mono_energy, 7000, 9000, 11, Obender, -2000, -1400, 13, snake_axes=False, md=md))  

mono_energy.move(8000)
Obender.move(-2000)

print(f"Energy setpoint: {mono_energy.get().energy_eV.setpoint:.1f} eV (readback: {mono_energy.get().energy_eV.setpoint:.1f} eV)")
print(f"Bender setpoint: {Obender.get().user_setpoint:.0f} µm (readback: {Obender.get().user_readback:.0f} µm)")
print(f"BCS linear motor: {bcs_linear_motor.get():.3f} mm")

uid_12 = RE(grid_scan([basler_5472], mono_energy, 7000, 9000, 11, Obender, -400, 0, 9, snake_axes=False, md=md))
# Out:
# Energy setpoint: 8000.0 eV (readback: 8000.0 eV)
# Bender setpoint: -2000 µm (readback: -2000 µm)
# BCS linear motor: 7.410 mm
#
#
# Transient Scan ID: 15     Time: 2026-05-29 22:44:55
# Persistent Unique Scan ID: 'e7eb5957-3248-40b7-a78c-59fb50eea1f8'
# New stream: 'baseline'
# Start-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8000.184027806925              |
# |         mono_energy_mono_angle | 20.755                         |
# |                      bender_um | -1999.98786                    |
# |               bcs_linear_motor | 7.409954                       |
# +--------------------------------+--------------------------------+
# New stream: 'primary'
# +-----------+------------+-----------------------+------------------------+------------+
# |   seq_num |       time | mono_energy_energy_eV | mono_energy_mono_angle |  bender_um |
# +-----------+------------+-----------------------+------------------------+------------+
# |         1 | 22:45:01.1 |              6999.820 |                22.8540 | -1999.98786 |
# |        76 | 23:08:02.7 |              8599.927 |                19.7380 | -250.01319 |
# |        77 | 23:08:08.5 |              8599.927 |                19.7380 | -200.01246 |
# |        78 | 23:08:14.4 |              8599.927 |                19.7380 | -150.01332 |
# |        79 | 23:08:20.3 |              8599.927 |                19.7380 | -100.01100 |
# |        80 | 23:08:26.1 |              8599.927 |                19.7380 |  -50.01345 |
# |        81 | 23:08:32.0 |              8599.927 |                19.7380 |   -0.01113 |
# |        82 | 23:08:41.4 |              8800.281 |                19.4300 | -399.99471 |
# |        83 | 23:08:47.3 |              8800.281 |                19.4300 | -350.01306 |
# |        84 | 23:08:53.2 |              8800.281 |                19.4300 | -300.01233 |
# |        85 | 23:08:59.2 |              8800.281 |                19.4300 | -250.01319 |
# |        86 | 23:09:05.1 |              8800.281 |                19.4300 | -200.01246 |
# |        87 | 23:09:11.0 |              8800.281 |                19.4300 | -150.01332 |
# |        88 | 23:09:16.9 |              8800.281 |                19.4300 | -100.01100 |
# |        89 | 23:09:22.8 |              8800.281 |                19.4300 |  -50.01345 |
# |        90 | 23:09:28.7 |              8800.281 |                19.4300 |   -0.01113 |
# |        91 | 23:09:38.1 |              8999.986 |                19.1370 | -399.99471 |
# |        92 | 23:09:43.9 |              8999.986 |                19.1370 | -350.01306 |
# |        93 | 23:09:49.8 |              8999.986 |                19.1370 | -300.01233 |
# |        94 | 23:09:55.6 |              8999.986 |                19.1370 | -250.01478 |
# |        95 | 23:10:01.5 |              8999.986 |                19.1370 | -200.01246 |
# |        96 | 23:10:07.3 |              8999.986 |                19.1370 | -150.01332 |
# |        97 | 23:10:13.2 |              8999.986 |                19.1370 | -100.01100 |
# |        98 | 23:10:19.2 |              8999.986 |                19.1370 |  -50.01345 |
# |        99 | 23:10:25.1 |              8999.986 |                19.1370 |   -0.01272 |
# +-----------+------------+-----------------------+------------------------+------------+
# generator grid_scan ['263e5125'] (scan num: 16)
# End-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8999.986357882728              |
# |         mono_energy_mono_angle | 19.137                         |
# |                      bender_um | -0.01272                       |
# |               bcs_linear_motor | 7.409954                       |
# +--------------------------------+--------------------------------+

# %% [markdown]
# Forgot to move `bcs_linear_motor` further up.

# %%
mono_energy.move(8000)
Obender.move(-2000)

print(f"Energy setpoint: {mono_energy.get().energy_eV.setpoint:.1f} eV (readback: {mono_energy.get().energy_eV.setpoint:.1f} eV)")
print(f"Bender setpoint: {Obender.get().user_setpoint:.0f} µm (readback: {Obender.get().user_readback:.0f} µm)")
print(f"BCS linear motor: {bcs_linear_motor.get():.3f} mm")

uid_13 = RE(bp.scan([basler_5472], bcs_linear_motor, 7.899, 7.900, 2))
# Out:
# Energy setpoint: 8000.0 eV (readback: 8000.0 eV)
# Bender setpoint: -2000 µm (readback: -2000 µm)
# BCS linear motor: 7.410 mm
#
#
# Transient Scan ID: 17     Time: 2026-05-29 23:22:13
# Persistent Unique Scan ID: '70891aa8-0b9e-48c3-924e-e453787b5c42'
# New stream: 'baseline'
# Start-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8000.184027806925              |
# |         mono_energy_mono_angle | 20.755                         |
# |                      bender_um | -1999.98786                    |
# |               bcs_linear_motor | 7.409954                       |
# +--------------------------------+--------------------------------+
# New stream: 'primary'
# +-----------+------------+------------------+
# |   seq_num |       time | bcs_linear_motor |
# +-----------+------------+------------------+
# |         1 | 23:22:19.0 |            7.899 |
# |         2 | 23:22:24.5 |            7.900 |
# +-----------+------------+------------------+
# generator scan ['70891aa8'] (scan num: 17)
# End-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8000.184027806925              |
# |         mono_energy_mono_angle | 20.755                         |
# |                      bender_um | -1999.98786                    |
# |               bcs_linear_motor | 7.899995                       |
# +--------------------------------+--------------------------------+

# %%
db = tiled_client[uid_13]

# Metadata
# wfs_chip_pos_mm = db['baseline']['bcs_linear_motor'].read()
bender_um = db['baseline']['bender_um'].read()
energy_eV = db['baseline']['mono_energy_energy_eV'].read()

# Data arrays (slow)
images    = db['primary']['basler_5472_image'].read()  
wfs_chip_pos_mm = db['primary']['bcs_linear_motor'].read()  

idx = 1

plt.figure(figsize=(12, 5))
plt.imshow(images[idx].T, cmap='hot', interpolation='nearest', vmax=4000)
plt.title(f'idx=0   E={energy_eV[0]:.0f} eV   bender={bender_um[0]:.0f} µm   chip_pos={wfs_chip_pos_mm[idx]:.3f} mm', fontsize=12)
plt.xlabel('y [pixels]')
plt.ylabel('x [pixels]')
plt.colorbar(label='Intensity [counts]')
plt.tight_layout()
plt.show()

# %%
from bluesky.plans import grid_scan

mono_energy.move(8000)
Obender.move(-2000)

print(f"Energy setpoint: {mono_energy.get().energy_eV.setpoint:.1f} eV (readback: {mono_energy.get().energy_eV.setpoint:.1f} eV)")
print(f"Bender setpoint: {Obender.get().user_setpoint:.0f} µm (readback: {Obender.get().user_readback:.0f} µm)")
print(f"BCS linear motor: {bcs_linear_motor.get():.3f} mm")

uid_14 = RE(grid_scan([basler_5472], mono_energy, 7000, 9000, 11, Obender, -2000, -1400, 13, snake_axes=False, md=md))  

mono_energy.move(8000)
Obender.move(-2000)

print(f"Energy setpoint: {mono_energy.get().energy_eV.setpoint:.1f} eV (readback: {mono_energy.get().energy_eV.setpoint:.1f} eV)")
print(f"Bender setpoint: {Obender.get().user_setpoint:.0f} µm (readback: {Obender.get().user_readback:.0f} µm)")
print(f"BCS linear motor: {bcs_linear_motor.get():.3f} mm")

uid_15 = RE(grid_scan([basler_5472], mono_energy, 7000, 9000, 11, Obender, -400, 0, 9, snake_axes=False, md=md))
# Out:
# Energy setpoint: 8000.0 eV (readback: 8000.0 eV)
# Bender setpoint: -2000 µm (readback: -2000 µm)
# BCS linear motor: 7.900 mm
#
#
# Transient Scan ID: 18     Time: 2026-05-29 23:24:19
# Persistent Unique Scan ID: '5dbef69f-1e5b-43f3-8950-7118053075a1'
# New stream: 'baseline'
# Start-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 
of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8000.184027806925              |
# |         mono_energy_mono_angle | 20.755                         |
# |                      bender_um | -1999.98786                    |
# |               bcs_linear_motor | 7.899995                       |
# +--------------------------------+--------------------------------+
# New stream: 'primary'
# +-----------+------------+-----------------------+------------------------+------------+
# |   seq_num |       time | mono_energy_energy_eV | mono_energy_mono_angle |  bender_um |
# +-----------+------------+-----------------------+------------------------+------------+
# |         1 | 23:39:46.4 |              6999.820 |                22.8540 | -400.01379 |
# |         2 | 23:39:52.2 |              6999.820 |                22.8540 | -350.01465 |
# |         3 | 23:39:58.0 |              6999.820 |                22.8540 | -300.01233 |
# |         4 | 23:40:03.7 |              6999.820 |                22.8540 | -250.01319 |
# |         5 | 23:40:09.5 |              6999.820 |                22.8540 | -200.01405 |
# |         6 | 23:40:15.2 |              6999.820 |                22.8540 | -150.01332 |
# |         7 | 23:40:21.1 |              6999.820 |                22.8540 | -100.01100 |
# |         8 | 23:40:26.8 |              6999.820 |                22.8540 |  -50.01345 |
# |         9 | 23:40:32.6 |              6999.820 |                22.8540 |   -0.01272 |
# |        10 | 23:40:42.0 |              7199.754 |                22.3860 | -399.99471 |
# |        11 | 23:40:47.7 |              7199.754 |                22.3860 | -350.01306 |
# |        12 | 23:40:53.4 |              7199.754 |                22.3860 | -300.01233 |
# |        13 | 23:40:59.2 |              7199.754 |                22.3860 | -250.01478 |
# |        14 | 23:41:04.9 |              7199.754 |                22.3860 | -200.01246 |
# |        15 | 23:41:10.7 |              7199.754 |                22.3860 | -150.01332 |
# |        16 | 23:41:16.4 |              7199.754 |                22.3860 | -100.01100 |
# |        17 | 23:41:22.2 |              7199.754 |                22.3860 |  -50.01345 |
# |        18 | 23:41:28.1 |              7199.754 |                22.3860 |   -0.01272 |
# |        19 | 23:41:37.3 |              7399.825 |                21.9440 | -399.99471 |
# |        20 | 23:41:43.1 |              7399.825 |                21.9440 | -350.01306 |
# |        21 | 23:41:48.9 |              7399.825 |                21.9440 | -300.01233 |
# |        22 | 23:41:54.6 |              7399.825 |                21.9440 | -250.01319 |
# |        23 | 23:42:00.4 |              7399.825 |                21.9440 | -200.01246 |
# |        24 | 23:42:06.2 |              7399.825 |                21.9440 | -150.01332 |
# |        25 | 23:42:12.0 |              7399.825 |                21.9440 | -100.01100 |
# |        26 | 23:42:17.8 |              7399.825 |                21.9440 |  -50.01345 |
# |        27 | 23:42:23.6 |              7399.825 |                21.9440 |   -0.01272 |
# |        28 | 23:42:33.0 |              7599.966 |                21.5260 | -399.99471 |
# |        29 | 23:42:38.7 |              7599.966 |                21.5260 | -350.01306 |
# |        30 | 23:42:44.6 |              7599.966 |                21.5260 | -300.01233 |
# |        31 | 23:42:50.4 |              7599.966 |                21.5260 | -250.01319 |
# |        32 | 23:42:56.3 |              7599.966 |                21.5260 | -200.01246 |
# |        33 | 23:43:02.1 |              7599.966 |                21.5260 | -150.01332 |
# |        34 | 23:43:07.9 |              7599.966 |                21.5260 | -100.01100 |
# |        35 | 23:43:13.7 |              7599.966 |                21.5260 |  -50.01345 |
# |        36 | 23:43:19.4 |              7599.966 |                21.5260 |   -0.01272 |
# |        75 | 23:47:23.9 |              8599.927 |                19.7380 | -300.01233 |
# |        76 | 23:47:29.8 |              8599.927 |                19.7380 | -250.01478 |
# |        77 | 23:47:35.6 |              8599.927 |                19.7380 | -200.01246 |
# |        78 | 23:47:41.5 |              8599.927 |                19.7380 | -150.01332 |
# |        79 | 23:47:47.3 |              8599.927 |                19.7380 | -100.01100 |
# |        80 | 23:47:53.3 |              8599.927 |                19.7380 |  -50.01345 |
# |        81 | 23:47:59.2 |              8599.927 |                19.7380 |   -0.01272 |
# |        82 | 23:48:08.4 |              8800.281 |                19.4300 | -399.99471 |
# |        83 | 23:48:14.3 |              8800.281 |                19.4300 | -350.01306 |
# |        84 | 23:48:20.1 |              8800.281 |                19.4300 | -300.01233 |
# |        85 | 23:48:26.0 |              8800.281 |                19.4300 | -250.01319 |
# |        86 | 23:48:31.9 |              8800.281 |                19.4300 | -200.01246 |
# |        87 | 23:48:37.8 |              8800.281 |                19.4300 | -150.01332 |
# |        88 | 23:48:43.6 |              8800.281 |                19.4300 | -100.01100 |
# |        89 | 23:48:49.5 |              8800.281 |                19.4300 |  -50.01345 |
# |        90 | 23:48:55.4 |              8800.281 |                19.4300 |   -0.01272 |
# |        91 | 23:49:04.8 |              8999.986 |                19.1370 | -399.99312 |
# |        92 | 23:49:10.7 |              8999.986 |                19.1370 | -350.01306 |
# |        93 | 23:49:16.7 |              8999.986 |                19.1370 | -300.01233 |
# |        94 | 23:49:22.6 |              8999.986 |                19.1370 | -250.01319 |
# |        95 | 23:49:28.5 |              8999.986 |                19.1370 | -200.01246 |
# |        96 | 23:49:34.4 |              8999.986 |                19.1370 | -150.01332 |
# |        97 | 23:49:40.2 |              8999.986 |                19.1370 | -100.01100 |
# |        98 | 23:49:46.1 |              8999.986 |                19.1370 |  -50.01345 |
# |        99 | 23:49:52.0 |              8999.986 |                19.1370 |   -0.01272 |
# +-----------+------------+-----------------------+------------------------+------------+
# generator grid_scan ['301119ed'] (scan num: 19)
# End-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8999.986357882728              |
# |         mono_energy_mono_angle | 19.137                         |
# |                      bender_um | -0.01272                       |
# |               bcs_linear_motor | 7.899995                       |
# +--------------------------------+--------------------------------+

# %%
mono_energy.move(8000)
Obender.move(-2000)

print(f"Energy setpoint: {mono_energy.get().energy_eV.setpoint:.1f} eV (readback: {mono_energy.get().energy_eV.setpoint:.1f} eV)")
print(f"Bender setpoint: {Obender.get().user_setpoint:.0f} µm (readback: {Obender.get().user_readback:.0f} µm)")
print(f"BCS linear motor: {bcs_linear_motor.get():.3f} mm")

uid_16 = RE(bp.scan([basler_5472], bcs_linear_motor, 7.901, 8.100, 200))

uid_17 = RE(bp.scan([basler_5472], bcs_linear_motor, 8.900, 9.100, 201))
# Out:
# Energy setpoint: 8000.0 eV (readback: 8000.0 eV)
# Bender setpoint: -2000 µm (readback: -2000 µm)
# BCS linear motor: 7.900 mm
#
#
# Transient Scan ID: 20     Time: 2026-05-29 23:52:58
# Persistent Unique Scan ID: 'a0883ecc-84b2-4096-9ee3-5f46e061a9b0'
# New stream: 'baseline'
# Start-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8000.184027806925              |
# |         mono_energy_mono_angle | 20.755                         |
# |                      bender_um | -1999.98786                    |
# |               bcs_linear_motor | 7.899995                       |
# +--------------------------------+--------------------------------+
# New stream: 'primary'
# +-----------+------------+------------------+
# |   seq_num |       time | bcs_linear_motor |
# +-----------+------------+------------------+
# |         1 | 23:53:03.7 |            7.901 |
# |         2 | 23:53:09.2 |            7.902 |
# |         3 | 23:53:14.5 |            7.903 |
# |         4 | 23:53:19.9 |            7.904 |
# |         5 | 23:53:25.2 |            7.905 |
# |         6 | 23:53:30.6 |            7.906 |
# |         7 | 23:53:36.0 |            7.907 |
# |         8 | 23:53:41.3 |            7.908 |
# |         9 | 23:53:46.7 |            7.909 |
# |        10 | 23:53:52.0 |            7.910 |
# |        11 | 23:53:57.4 |            7.911 |
# |        12 | 23:54:02.8 |            7.912 |
# |        13 | 23:54:08.2 |            7.913 |
# |        14 | 23:54:13.6 |            7.914 |
# |        15 | 23:54:18.9 |            7.915 |
# |        16 | 23:54:24.3 |            7.916 |
# |        17 | 23:54:29.7 |            7.917 |
# |        18 | 23:54:35.0 |            7.918 |
# |        19 | 23:54:40.4 |            7.919 |
# |        20 | 23:54:45.7 |            7.920 |
# |        21 | 23:54:51.1 |            7.921 |
# |        22 | 23:54:56.5 |            7.922 |
# |        23 | 23:55:01.9 |            7.923 |
# |        24 | 23:55:07.2 |            7.924 |
# |        25 | 23:55:12.6 |            7.925 |
# |        26 | 23:55:18.0 |            7.926 |
# |        27 | 23:55:23.4 |            7.927 |
# |        28 | 23:55:28.8 |            7.928 |
# |        29 | 23:55:34.2 |            7.929 |
# |        30 | 23:55:39.6 |            7.930 |
# |        31 | 23:55:45.0 |            7.931 |
# |        32 | 23:55:50.4 |            7.932 |
# |        33 | 23:55:55.8 |            7.933 |
# |        34 | 23:56:01.2 |            7.934 |
# |        35 | 23:56:06.6 |            7.935 |
# |        36 | 23:56:12.0 |            7.936 |
# |        37 | 23:56:17.5 |            7.937 |
# |        38 | 23:56:22.9 |            7.938 |
# |        39 | 23:56:28.3 |            7.939 |
# |        40 | 23:56:33.8 |            7.940 |
# |        41 | 23:56:39.2 |            7.941 |
# |        42 | 23:56:44.6 |            7.942 |
# |        43 | 23:56:50.0 |            7.943 |
# |        44 | 23:56:55.5 |            7.944 |
# |        45 | 23:57:02.1 |            7.945 |
# |        46 | 23:57:07.5 |            7.946 |
# |        47 | 23:57:13.0 |            7.947 |
# |        48 | 23:57:18.4 |            7.948 |
# |        49 | 23:57:23.8 |            7.949 |
# +-----------+------------+------------------+
# |   seq_num |       time | bcs_linear_motor |
# +-----------+------------+------------------+
# |        50 | 23:57:29.3 |            7.950 |
# |        51 | 23:57:34.7 |            7.951 |
# |        52 | 23:57:40.1 |            7.952 |
# |        53 | 23:57:45.5 |            7.953 |
# |        54 | 23:57:51.0 |            7.954 |
# |        55 | 23:57:56.4 |            7.955 |
# |        56 | 23:58:01.9 |            7.956 |
# |        57 | 23:58:07.3 |            7.957 |
# |       187 | 00:10:08.0 |            8.087 |
# |       188 | 00:10:13.6 |            8.088 |
# |       189 | 00:10:19.3 |            8.089 |
# |       190 | 00:10:25.0 |            8.090 |
# |       191 | 00:10:30.6 |            8.091 |
# |       192 | 00:10:36.2 |            8.092 |
# |       193 | 00:10:41.9 |            8.093 |
# |       194 | 00:10:47.6 |            8.094 |
# |       195 | 00:10:53.2 |            8.095 |
# |       196 | 00:10:58.8 |            8.096 |
# |       197 | 00:11:04.5 |            8.097 |
# |       198 | 00:11:10.1 |            8.098 |
# |       199 | 00:11:15.8 |            8.099 |
# +-----------+------------+------------------+
# |   seq_num |       time | bcs_linear_motor |
# +-----------+------------+------------------+
# |       200 | 00:11:21.4 |            8.100 |
# +-----------+------------+------------------+
# generator scan ['a0883ecc'] (scan num: 20)
# End-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8000.184027806925              |
# |         mono_energy_mono_angle | 20.755                         |
# |                      bender_um | -1999.98786                    |
# |               bcs_linear_motor | 8.10002                        |
# +--------------------------------+--------------------------------+
#
#
#
#
#
# Transient Scan ID: 21     Time: 2026-05-30 00:11:22
# Persistent Unique Scan ID: '67396878-25a5-459d-a6b5-cd0fe571a6f0'
# New stream: 'baseline'
# Start-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8000.184027806925              |
# |         mono_energy_mono_angle | 20.755                         |
# |                      bender_um | -1999.98786                    |
# |               bcs_linear_motor | 8.10002                        |
# +--------------------------------+--------------------------------+
# New stream: 'primary'
# +-----------+------------+------------------+
# |   seq_num |       time | bcs_linear_motor |
# +-----------+------------+------------------+
# |         1 | 00:11:28.6 |            8.900 |
# |         2 | 00:11:34.1 |            8.901 |
# |         3 | 00:11:39.4 |            8.902 |
# |         4 | 00:11:44.8 |            8.903 |
# |         5 | 00:11:50.2 |            8.904 |
# |         6 | 00:11:55.5 |            8.905 |
# |         7 | 00:12:00.9 |            8.906 |
# |         8 | 00:12:06.3 |            8.907 |
# |         9 | 00:12:11.6 |            8.908 |
# |        10 | 00:12:17.0 |            8.909 |
# |        11 | 00:12:22.4 |            8.910 |
# |        12 | 00:12:27.7 |            8.911 |
# |        13 | 00:12:33.1 |            8.912 |
# |        14 | 00:12:38.5 |            8.913 |
# |        15 | 00:12:43.8 |            8.914 |
# |        16 | 00:12:49.2 |            8.915 |
# |        17 | 00:12:54.6 |            8.916 |
# |        18 | 00:13:00.0 |            8.917 |
# |        19 | 00:13:05.4 |            8.918 |
# |        20 | 00:13:10.7 |            8.919 |
# |        21 | 00:13:16.2 |            8.920 |
# |        22 | 00:13:21.6 |            8.921 |
# |        23 | 00:13:26.9 |            8.922 |
# |        24 | 00:13:32.3 |            8.923 |
# |        25 | 00:13:37.7 |            8.924 |
# |        26 | 00:13:43.1 |            8.925 |
# |        27 | 00:13:48.5 |            8.926 |
# |        28 | 00:13:53.9 |            8.927 |
# |        29 | 00:13:59.2 |            8.928 |
# |        30 | 00:14:04.6 |            8.929 |
# |        31 | 00:14:10.0 |            8.930 |
# |        32 | 00:14:15.4 |            8.931 |
# |        33 | 00:14:20.8 |            8.932 |
# |        34 | 00:14:26.2 |            8.933 |
# |       161 | 00:26:05.1 |            9.060 |
# |       162 | 00:26:10.8 |            9.061 |
# |       163 | 00:26:16.4 |            9.062 |
# |       164 | 00:26:22.0 |            9.063 |
# |       165 | 00:26:27.5 |            9.064 |
# |       166 | 00:26:33.2 |            9.065 |
# |       167 | 00:26:38.8 |            9.066 |
# |       168 | 00:26:44.4 |            9.067 |
# |       169 | 00:26:49.9 |            9.068 |
# |       170 | 00:26:55.5 |            9.069 |
# |       171 | 00:27:01.1 |            9.070 |
# |       172 | 00:27:06.7 |            9.071 |
# |       173 | 00:27:12.3 |            9.072 |
# |       174 | 00:27:17.9 |            9.073 |
# |       175 | 00:27:23.5 |            9.074 |
# |       176 | 00:27:29.1 |            9.075 |
# |       177 | 00:27:34.7 |            9.076 |
# |       178 | 00:27:40.3 |            9.077 |
# |       179 | 00:27:45.9 |            9.078 |
# |       180 | 00:27:51.5 |            9.079 |
# |       181 | 00:27:57.1 |            9.080 |
# |       182 | 00:28:02.7 |            9.081 |
# |       183 | 00:28:08.5 |            9.082 |
# |       184 | 00:28:14.1 |            9.083 |
# |       185 | 00:28:19.7 |            9.084 |
# |       186 | 00:28:25.4 |            9.085 |
# |       187 | 00:28:31.0 |            9.086 |
# |       188 | 00:28:36.6 |            9.087 |
# |       189 | 00:28:42.2 |            9.088 |
# |       190 | 00:28:47.8 |            9.089 |
# |       191 | 00:28:53.5 |            9.090 |
# |       192 | 00:28:59.1 |            9.091 |
# |       193 | 00:29:04.7 |            9.092 |
# |       194 | 00:29:10.3 |            9.093 |
# |       195 | 00:29:15.9 |            9.094 |
# |       196 | 00:29:21.6 |            9.095 |
# |       197 | 00:29:27.2 |            9.096 |
# |       198 | 00:29:32.9 |            9.097 |
# |       199 | 00:29:38.5 |            9.098 |
# +-----------+------------+------------------+
# |   seq_num |       time | bcs_linear_motor |
# +-----------+------------+------------------+
# |       200 | 00:29:44.2 |            9.099 |
# |       201 | 00:29:49.9 |            9.100 |
# +-----------+------------+------------------+
# generator scan ['67396878'] (scan num: 21)
# End-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8000.184027806925              |
# |         mono_energy_mono_angle | 20.755                         |
# |                      bender_um | -1999.98786                    |
# |               bcs_linear_motor | 9.100046                       |
# +--------------------------------+--------------------------------+

# %%
uid = RE(bp.count([basler_5472], num=1, md = md))
# Out:
# Transient Scan ID: 22     Time: 2026-05-30 12:07:47
# Persistent Unique Scan ID: '37c5bd50-1c23-47e7-bf8e-ee960ca47dcd'
# New stream: 'baseline'
# Start-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8000.184027806925              |
# |         mono_energy_mono_angle | 20.755                         |
# |                      bender_um | -1999.98786                    |
# |               bcs_linear_motor | 9.100046                       |
# +--------------------------------+--------------------------------+
# New stream: 'primary'
# +-----------+------------+
# |   seq_num |       time |
# +-----------+------------+
# |         1 | 12:07:50.2 |
# +-----------+------------+
# generator count ['37c5bd50'] (scan num: 22)
# End-of-run baseline readings:
# +--------------------------------+--------------------------------+
# |          mono_energy_energy_eV | 8000.184027806925              |
# |         mono_energy_mono_angle | 20.755                         |
# |                      bender_um | -1999.98786                    |
# |               bcs_linear_motor | 9.100046                       |
# +--------------------------------+--------------------------------+

# %%
db = tiled_client[uid]

# Metadata
wfs_chip_pos_mm = db['baseline']['bcs_linear_motor'].read()
bender_um = db['baseline']['bender_um'].read()
energy_eV = db['baseline']['mono_energy_energy_eV'].read()

print(f"WFS chip position (mm): {wfs_chip_pos_mm}")
print(f"Mono energy (eV): {energy_eV}")
print(f"Bender position (µm): {bender_um}")

# Data arrays (slow)
images    = db['primary']['basler_5472_image'].read()  
# wfs_chip_pos_mm = db['primary']['bcs_linear_motor'].read()   
# energy_eV = db['primary']['mono_energy_energy_eV'].read() 
# bender_um = db['primary']['bender_um'].read() 

# Print summaries
print(f"\nImages shape: {images.shape}  (n_frames × height × width)")
# print(f"Energy range: {energy_eV.min():.1f} – {energy_eV.max():.1f} eV")
# print(f"       shape: {energy_eV.shape}")
# print(f"Bender range: {bender_um.min():.1f} – {bender_um.max():.1f} µm")
# print(f"       shape: {bender_um.shape}")
# print(f"WFS chip position range: {wfs_chip_pos_mm.min():.3f} – {wfs_chip_pos_mm.max():.3f} mm")
# print(f"       shape: {wfs_chip_pos_mm.shape}")
# Out:
# WFS chip position (mm): [9.100046 9.100046]
# Mono energy (eV): [8000.18402781 8000.18402781]
# Bender position (µm): [-1999.98786 -1999.98786]
#
# Images shape: (1, 2900, 1100)  (n_frames × height × width)

# %%
plt.figure(figsize=(8, 3))
plt.imshow(images[0].T, cmap='hot', interpolation='nearest', vmax=100)
plt.title(f'idx=0   E={energy_eV[0]:.0f} eV   bender={bender_um[0]:.0f} µm   chip_pos={wfs_chip_pos_mm[0]:.3f} mm', fontsize=12)
plt.xlabel('y [pixels]')
plt.ylabel('x [pixels]')
plt.colorbar(label='Intensity [counts]')
plt.tight_layout()
plt.show()
# Out:
# CA.Client.Exception...............................................
#     Warning: "Virtual circuit disconnect"
#     Context: "192.168.10.124:46463"
#     Source File: modules/ca/src/client/cac.cpp line 1237
#     Current Time: Sun May 31 2026 11:00:18.839092749
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Virtual circuit disconnect"
#     Context: "192.168.10.124:36087"
#     Source File: modules/ca/src/client/cac.cpp line 1237
#     Current Time: Sun May 31 2026 13:59:12.635119197
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Virtual circuit disconnect"
#     Context: "192.168.10.124:40543"
#     Source File: modules/ca/src/client/cac.cpp line 1237
#     Current Time: Tue Jun 02 2026 15:26:03.066827851
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Virtual circuit disconnect"
#     Context: "192.168.10.124:42231"
#     Source File: modules/ca/src/client/cac.cpp line 1237
#     Current Time: Wed Jun 03 2026 09:21:29.561228051
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Virtual circuit disconnect"
#     Context: "192.168.10.124:35399"
#     Source File: modules/ca/src/client/cac.cpp line 1237
#     Current Time: Wed Jun 03 2026 13:43:37.845690863
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Virtual circuit disconnect"
#     Context: "192.168.10.124:37567"
#     Source File: modules/ca/src/client/cac.cpp line 1237
#     Current Time: Wed Jun 03 2026 17:17:47.582364047
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Virtual circuit disconnect"
#     Context: "192.168.10.124:34745"
#     Source File: modules/ca/src/client/cac.cpp line 1237
#     Current Time: Wed Jun 03 2026 22:14:10.049245696
# ..................................................................
